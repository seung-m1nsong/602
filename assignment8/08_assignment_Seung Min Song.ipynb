# %% [markdown]
# <a href="https://colab.research.google.com/github/data602sps/assignments/blob/master/05_assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Assignment 8**
#
# # **Weeks 10 & 11 - matplotlib & seaborn**
# * In this homework assignment, you will explore and analyze a public dataset of your choosing. Since this assignment is “open-ended” in nature, you are free to expand upon the requirements below. However, you must meet the minimum requirments as indicated in each section.
#
#
# * The preferred method for this analysis is in a .ipynb file. Feel free to use whichever platform of your choosing.
#
#
# ### **Some data examples:**
# •	https://www.data.gov/
#
# •	https://opendata.cityofnewyork.us/
#
# •	https://datasetsearch.research.google.com/
#
# •	https://archive.ics.uci.edu/ml/index.php
#
# ### **Resources:**
#
# •	https://pandas.pydata.org/pandas-docs/stable/getting_started/10min.html
#
# •	https://www.oreilly.com/library/view/python-data-science/9781491912126/ch04.html
#
# •	https://www.data-to-viz.com/
#
#
#
# ### **Headings or comments**
# **You are required to make use of comments, or headings for each section.  You must explain what your code is doing, and the results of running your code.**  Act as if you were giving this assignment to your manager - you must include clear and descriptive information for each section.
#
# ### **You may work as a group or indivdually on this assignment.**

# %% [markdown]
# # Introduction
#
# In this section, please describe the dataset you are using.  Include a link to the source of this data.  You should also provide some explanation on why you choose this dataset.

# %% [markdown]
# **Data Source**
#
# Downloaded the csv data table from the link below:
# * kaggle.com/datasets/uciml/student-alcohol-consumption
#
# **Data collection**
#
# * student-mat.csv
# * student-por.csv
#
# **Explanation on Data**
#
# The data were obtained in a survey of students math and portuguese language courses in secondary school. As a graduate student who is planning to raise a child, this study may be relevant to you as it explores the external factors that have an impact on students' final grades. By analyzing the various external variables that can influence academic performance, this study provides valuable insights that can help parents, educators, and policymakers to better support students' success in school. Specifically, this study looks at factors such as students' health, social and demographic factors, study habits, and other relevant factors that can have an impact on their academic performance.
#
# **Attributes for df_student**
#
# * school - student's school (binary: 'GP' - Gabriel Pereira or 'MS' - Mousinho da Silveira)
# * sex - student's sex (binary: 'F' - female or 'M' - male)
# * age - student's age (numeric: from 15 to 22)
# * address - student's home address type (binary: 'U' - urban or 'R' - rural)
# * famsize - family size (binary: 'LE3' - less or equal to 3 or 'GT3' - greater than 3)
# * Pstatus - parent's cohabitation status (binary: 'T' - living together or 'A' - apart)
# * Medu - mother's education (numeric: 0 - none, 1 - primary education (4th grade), 2 – 5th to 9th grade, 3 – secondary education or 4 – higher education)
# * Fedu - father's education (numeric: 0 - none, 1 - primary education (4th grade), 2 – 5th to 9th grade, 3 – secondary education or 4 – higher education)
# * Mjob - mother's job (nominal: 'teacher', 'health' care related, civil 'services' (e.g. administrative or police), 'at_home' or 'other')
# * Fjob - father's job (nominal: 'teacher', 'health' care related, civil 'services' (e.g. administrative or police), 'at_home' or 'other')
# * reason - reason to choose this school (nominal: close to 'home', school 'reputation', 'course' preference or 'other')
# * guardian - student's guardian (nominal: 'mother', 'father' or 'other')
# * traveltime - home to school travel time (numeric: 1 - <15 min., 2 - 15 to 30 min., 3 - 30 min. to 1 hour, or 4 - >1 hour)
# * studytime - weekly study time (numeric: 1 - <2 hours, 2 - 2 to 5 hours, 3 - 5 to 10 hours, or 4 - >10 hours)
# * failures - number of past class failures (numeric: n if 1<=n<3, else 4)
# * schoolsup - extra educational support (binary: yes or no)
# * famsup - family educational support (binary: yes or no)
# * paid - extra paid classes within the course subject (Math or Portuguese) (binary: yes or no)
# * activities - extra-curricular activities (binary: yes or no)
# * nursery - attended nursery school (binary: yes or no)
# * higher - wants to take higher education (binary: yes or no)
# * internet - Internet access at home (binary: yes or no)
# * romantic - with a romantic relationship (binary: yes or no)
# * famrel - quality of family relationships (numeric: from 1 - very bad to 5 - excellent)
# * freetime - free time after school (numeric: from 1 - very low to 5 - very high)
# * goout - going out with friends (numeric: from 1 - very low to 5 - very high)
# * Dalc - workday alcohol consumption (numeric: from 1 - very low to 5 - very high)
# * Walc - weekend alcohol consumption (numeric: from 1 - very low to 5 - very high)
# * health - current health status (numeric: from 1 - very bad to 5 - very good)
# * absences - number of school absences (numeric: from 0 to 93)
# * These grades are related with the course subject, Math or Portuguese:
# * G1 - first period grade (numeric: from 0 to 20)
# * G2 - second period grade (numeric: from 0 to 20)
# * G3 - final grade (numeric: from 0 to 20, output target)

# %% [markdown]
# ______________
# # Data Exploration
# Import your dataset into your .ipynb, create dataframes, and explore your data.
#
# Include:
#
# * Summary statistics means, medians, quartiles,
# * Missing value information
# * Any other relevant information about the dataset.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Student Math Dataframe
df_mat = pd.read_csv("https://raw.githubusercontent.com/seung-m1nsong/602/main/Final/student-mat.csv")

# Studnet Por Dataframe
df_por = pd.read_csv("https://raw.githubusercontent.com/seung-m1nsong/602/main/Final/student-por.csv")

# Summary statistics for student-mat.csv
print("Summary statistics for student-mat.csv:")
print(df_mat.describe())

# Summary statistics for student-por.csv
print("Summary statistics for student-por.csv:")
print(df_por.describe())

# check missing values in df_mat
print(df_mat.isnull().sum())

# check missing values in df_por
print(df_por.isnull().sum())
# The dataset is complete with no missing values.

# The dataset is complete with no missing values.

print(df_mat.info())
print(df_por.info())
# The dataframe df_mat contains 395 entries (rows) with 33 columns.
# The dataset df_por contains 649 entries (rows) with 33 columns. 
# The data types of the columns include integers (int64) and objects (object).
# The columns represent various features of the student dataset such as personal and family characteristics, academic performance, and social activities.
# Some of the columns include: school, sex, age, address, family size, parents' education, mother and father's occupation, travel time, study time, number of failures, support received from school
# and family, extra-curricular activities, health, and academic grades.
# Out:
# Summary statistics for student-mat.csv:
#               age        Medu        Fedu  traveltime   studytime    failures  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean    16.696203    2.749367    2.521519    1.448101    2.035443    0.334177
# std      1.276043    1.094735    1.088201    0.697505    0.839240    0.743651
# min     15.000000    0.000000    0.000000    1.000000    1.000000    0.000000
# 25%     16.000000    2.000000    2.000000    1.000000    1.000000    0.000000
# 50%     17.000000    3.000000    2.000000    1.000000    2.000000    0.000000
# 75%     18.000000    4.000000    3.000000    2.000000    2.000000    0.000000
# max     22.000000    4.000000    4.000000    4.000000    4.000000    3.000000
#
#            famrel    freetime       goout        Dalc        Walc      health  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# ...

# %% [markdown]
# # Data Wrangling
#
# Perform data wrangling.  You are free to use your best judgment here.  If you are stuck, look at previous assignment.

# %%
# 1. Modify multiple column names.
# change famsup to famEdsup, chage Dacl to dayAlc, change Walc to weekAlc, and change goout to friendtime
df_mat = df_mat.rename(columns={'famsup': 'famEdsup'})
df_mat = df_mat.rename(columns={'Dacl': 'dayAlc'})
df_mat = df_mat.rename(columns={'Walc': 'weekAlc'})
df_mat = df_mat.rename(columns={'goout': 'friendtime'})

df_por = df_por.rename(columns={'famsup': 'famEdsup'})
df_por = df_por.rename(columns={'Dacl': 'dayAlc'})
df_por = df_por.rename(columns={'Walc': 'weekAlc'})
df_por = df_por.rename(columns={'goout': 'friendtime'})

# 2. Look at the structure of your data – are any variables improperly coded? Such as strings or characters? Convert to correct structure if needed.
# The dataset has been cleaned and all columns have the appropriate data types.

# 3. Fix missing and invalid values in data.
# The dataset is complete with no missing values.


# 4. Create new columns based on existing columns or calculations.
# use the assign() method to create a new column named G1G2avg. Later I will compare this new column with G3 (Final) grade. 
df_mat = df_mat.assign(G1G2avg = (df_mat['G1'] + df_mat['G2'])/2)
print(df_mat.head())

df_por = df_por.assign(G1G2avg = (df_por['G1'] + df_por['G2'])/2)
print(df_mat.head())

# create a new column named 'class' with the value 'mat' and 'por'
df_mat['class'] = 'mat'
df_por['class'] = 'por'

#5. Drop column(s) from your dataset.
# drop df_mat index 1. However, I will store the data to df_new, because I don't want to modify the orginal data. 
#df_new = df_mat.drop(index=1)

#6. Drop a row(s) from your dataset.
# drop df_mat column 'school'. However, I will store the data to df_new, because I don't want to modify the orginal data. 
#df_new = df_mat.drop('school', axis=1)
#print(df_new.head())

#7. Sort your data based on multiple variables. 
# first I will combine the two dataset
df_student = pd.concat([df_mat, df_por], axis=0)
# Reset the index
df_student = df_student.reset_index(drop=True)
print(df_student)

# sort by sex first, and then by age using sort_values
#df_student.sort_values(['sex', 'age'], inplace=True)
#print(df_student)

#8. Filter your data based on some condition. 
# filter the data in df_student based on the condition where G3 grade is higher than G1G2avg
df_student_filtered = df_student[df_student['G3'] > df_student['G1G2avg']]
print(df_student_filtered)
# out of 1044 students, 561 students scored a higher grade than the combined average of G1 and G2.

#9. Convert all the string values to upper or lower cases in one column.
# use the str.lower() method to convert all the string values to lower case in the "school" column of df_student.
df_student["school"] = df_student["school"].str.lower()
print(df_student.head())

#10. Check whether numeric values are present in a given column of your dataframe.
#use the str.contains() method of pandas series along with a regular expression pattern to match numeric values.
#True means it contains numeric values.
numeric_present = df_student['famsize'].str.contains('\d').any()
print(numeric_present)

#11. Group your dataset by one column, and get the mean, min, and max values by group.

# • Groupby()
# • agg() or .apply() 
# group it with school and calculates the mean, min, and max values of the GIG2avg column for each group using the agg function. 
# school gp performed better than school ms.
df_group = df_student.groupby(['school']).agg({'G1G2avg': ['mean', 'min', 'max']})
print(df_group)

#12. Group your dataset by two columns and then sort the aggregated results within the groups.
# group it with school and class then calculates the mean, min, and max values of the GIG2avg column for each group using the agg function. 
df_group = df_student.groupby(['school', 'class']).agg({'G1G2avg': ['mean', 'min', 'max']})
# Sort the results within each group by descending order of the mean G1G2avg
df_group_sorted = df_group.sort_values(by=('G1G2avg', 'mean'), ascending=False)

print(df_group_sorted)

#13. Use the replace() method to replace values. Change all variable with Yes to 1  and No to 0.
df_student.replace({"yes": 1, "no": 0}, inplace=True)
print(df_student)

#14. Create a new DataFrame for the numeric columns and character columns separately.
df_n = df_student.select_dtypes(include='number')
df_c = df_student.select_dtypes(include='object')

df_student.to_csv('file_path/df_student.csv', index=False)
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   friendtime Dalc  weekAlc  health  absences  G1  G2  G3 G1G2avg class
# 0          4    1        1       3         6   5   6   6     5.5   mat
# 1          3    1        1       3         4   5   5   6     5.0   mat
# 2          2    2        3       3        10   7   8  10     7.5   mat
# 3          2    1        1       5         2  15  14  15    14.5   mat
# 4          2    1        2       5         4   6  10  10     8.0   mat
#
# [5 rows x 35 columns]
# ...

# %% [markdown]
# # Visualizations
#
# The main purpose of this assignment is to practice creating various visualizations using the matplotlib and seaborn library.
#
# ### **Part 1:**
# Using matplotlib, create ***two or more plots*** that incorporate at least **5** of the following properties:
#
# Note: these properties vary based on your data.  The goal is to practice creating visualizations and modifying its properties.
#
# *   Use and change a legend position
# *   Change a legend font size
# *   Place a legend outside of the plot
# *   Create a single legend for all subplots
# *   Change the title and x/y labels
# *   Change the marker, line colors, and line width
# *   Add annotations
# *   Modify Axis Text Ticks/Labels
# *   Change size of axis Labels
# *   Your own choice not included above
#
#
# Plots that you can create **include**:
#
# *   Scatter Plot
# *   Bar plot
# *   Line Chart
# *   Multi Plots (e.g. using .subplot()
# *   Histogram
#
# You can add another plot not listed here if it works better for your data.  This is not a complete list of plots to create.
#
# ### **Part 2:**
#
# Recreate the visualizations above using the Seaborn library as best as possible.
#
#
# **You are required to explain what each of your plots is representing. Plots without comments will not be accepted.**  In addition, please explain the properties you are showcasing.
#
#
# ### **Part 3:**
# In a comment or text box, explain the differences between creating a plot in matplotlib and seaborn, based on your above plots.

# %%
# Part 1
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Graph 1 (boxplot)
# Calculates the mean age of male and female students in the dataset using the groupby() function. The resulting plot shows two rows, one for each sex, with the corresponding mean age value for each.

df_agesex = df_student.groupby('sex')['age'].mean().reset_index()
print(df_agesex)
# The average age for females is 16.8 years and the average age for males is 16.7 years, based on the student dataset.

# groups the dataset by sex and finds the maximum age for each group. The resulting plot prints the maximum age for females and males separately.
max_age = df_student.groupby('sex')['age'].max()

# print maximum age for each sex
print("Maximum age for Female: ", max_age['F'])
print("Maximum age for Male: ", max_age['M'])

# create figure and axis objects
fig, ax = plt.subplots()

# Creates a box plot to compare the age distribution between males and females. The plot shows two boxes, one for each sex, with the interquartile range, median, and any outliers. The legend of the plot shows the corresponding sex to each box, and the plot title and axis labels are set accordingly. The legend is also moved outside of the plot area to avoid overlapping with the plot itself.

bp = ax.boxplot(x=[df_student[df_student['sex']=='F']['age'], df_student[df_student['sex']=='M']['age']], labels=['Female', 'Male'])

# change legend position and font size
ax.legend(loc='upper right', fontsize='small')

# place legend outside of plot
plt.subplots_adjust(right=0.8)
ax.legend(loc='center left', bbox_to_anchor=(1.05, 0.5))

# change title and x/y labels
ax.set_title('Age by Sex')
ax.set_xlabel('Sex')
ax.set_ylabel('Age')

# show plot
#plt.show()


# Graph 2(barplot)
# selects the columns of the dataframe that contain object data type (string) and stores them in a new dataframe called df_c.
df_c = df_student.select_dtypes(include='object')
print(df_c)


#  subsets the df_c dataframe to only include female students taking either Portuguese or Mathematics classes, and counts the number of students in each class using the value_counts() method. The resulting counts are stored in a variable called counts_f.
female_por_mat = df_c[(df_c['sex'] == 'F') & ((df_c['class'] == 'por') | (df_c['class'] == 'mat'))]

# Count the number of students in each class
counts_f= female_por_mat['class'].value_counts()

print(counts_f)

# Subset the dataframe to only include males taking Por or Mat.
male_por_mat = df_c[(df_c['sex'] == 'M') & ((df_c['class'] == 'por') | (df_c['class'] == 'mat'))]

# Count the number of students in each class.
counts_m= male_por_mat['class'].value_counts()

print(counts_m)

# Create a figure with two subplots
fig, axs = plt.subplots(1, 2, figsize=(10, 5))

# Plot the number of female students in each class on the first subplot
counts_f.plot(kind='bar', ax=axs[0], color='red', legend=False)
axs[0].set_title('Female students by class')
axs[0].set_xlabel('Class')
axs[0].set_ylabel('Number of students')

# Add annotations to the first subplot
for i, v in enumerate(counts_f):
    axs[0].text(i, v+3, str(v), ha='center')

# Plot the number of male students in each class on the second subplot
counts_m.plot(kind='bar', ax=axs[1], color='blue', legend=False)
axs[1].set_title('Male students by class')
axs[1].set_xlabel('Class')
axs[1].set_ylabel('Number of students')

# Adds annotations to each bar in the plot to display the exact number of students in each class. 
for i, v in enumerate(counts_m):
    axs[1].text(i, v+3, str(v), ha='center')
    
# Set the title for the overall figure and adjust the spacing and font.
fig.suptitle('Number of students by gender and class', fontsize=16)
fig.subplots_adjust(top=0.85)

# Show the plot
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   sex        age
# 0   F  16.768190
# 1   M  16.671082
# Maximum age for Female:  21
# Maximum age for Male:  22
#      school sex address famsize Pstatus      Mjob      Fjob  reason guardian  \
# 0        gp   F       U     GT3       A   at_home   teacher  course   mother
# 1        gp   F       U     GT3       T   at_home     other  course   father
# 2        gp   F       U     LE3       T   at_home     other   other   mother
# 3        gp   F       U     GT3       T    health  services    home   mother
# 4        gp   F       U     GT3       T     other     other    home   father
# ...     ...  ..     ...     ...     ...       ...       ...     ...      ...
# ...

# %%
# Part 2
import seaborn as sns
import matplotlib.pyplot as plt

# Graph 1
# Set style and font size.
sns.set_style('whitegrid')
sns.set(font_scale=1.2)

# Create boxplot with custom colors using palette and line width.
sns.boxplot(x=df_student["sex"], y=df_student["age"], palette={'F':'pink', 'M':'lightblue'}, linewidth=2)

# Set legend outside of plot.
plt.legend(title='Sex', loc='upper left', bbox_to_anchor=(1.05, 1))

# Change title and x/y labels
plt.title('Age by Sex', fontsize=18)
plt.xlabel('Sex', fontsize=14)
plt.ylabel('Age', fontsize=14)

# Change size of axis labels.
plt.gcf().set_size_inches(8, 6)

plt.show()

# Graph 2
# Set the style of the plot
sns.set_style("whitegrid")

# Create a figure with two subplots
fig, axs = plt.subplots(1, 2, figsize=(10, 5))

# Plot the number of female students in each class on the first subplot
sns.barplot(x=counts_f.index, y=counts_f.values, ax=axs[0], color='pink')
axs[0].set_title('Female students by class')
axs[0].set_xlabel('Class')
axs[0].set_ylabel('Number of students')

# Add annotations to the first subplot
for i, v in enumerate(counts_f):
    axs[0].text(i, v+3, str(v), ha='center')

# Plot the number of male students in each class on the second subplot
sns.barplot(x=counts_m.index, y=counts_m.values, ax=axs[1], color='lightblue')
axs[1].set_title('Male students by class')
axs[1].set_xlabel('Class')
axs[1].set_ylabel('Number of students')

# Add annotations to the second subplot
for i, v in enumerate(counts_m):
    axs[1].text(i, v+3, str(v), ha='center')

# Set the title for the overall figure and adjust the spacing and font
fig.suptitle('Number of students by gender and class', fontsize=16)
fig.subplots_adjust(top=0.85)

# Show the plot
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# # Conclusions
#
# After exploring your dataset, provide a short summary of what you noticed from this dataset.

# %% [markdown]
# I have noticed that the database contains several character variable. If I am planning to perform statistical analysis, it is generally recommended to convert all categorical variables to numeric variables for easier handling and interpretation of the results. However, if I am performing some exploratory data analysis, keeping some variables as categorical may be useful in gaining insights about the data.
#
# In order to identify the factors that influence student grades, I plan to conduct a regression analysis that includes both binary and non-binary variables. This approach will help me to better understand the relationship between the dependent variable and one or more independent variables.
